# %% [markdown]
# # **> Cadastro de Regiões Metropolitanas**
# Para relacionar cada código a determinada
# região metropolitana cadastrada.

# %%
# !pip install gcsfs
# !pip install pandas-gbq

# %%
import pandas as pd
import numpy as np
from pandas_gbq import to_gbq

# %%
dim_rm = pd.read_csv("gs://tech3-dados-covid/regioes_metropolitanas.csv",encoding="latin1",sep=";")

# %%
dim_rm = dim_rm.rename(columns={
    "Categoria - Tipo ": "ID_RM",
    "Categoria - Descrição": "Região Metropolitana"
})

# %%
to_gbq(
    dim_rm,
    destination_table="tech3_pesquisa_covid.GOLD_DIM_REGIAO_METROPOLITANA",
    project_id="project-d5e304e6-93c5-44ee-974",
    if_exists="replace"
)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 6775.94it/s]
